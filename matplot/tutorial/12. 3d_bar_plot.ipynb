# %%
# %matplotlib inline
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
# 4 dataset , each contain 20 values
for c,z in zip(['r', 'g', 'b', 'y'], [30,20,10,0]):
    xs = np.arange(20) #preparing data for each dataset : x
    ys = np.random.rand(20) ##preparing data for each dataset : Y
    # Z values coming from for loop
    cs = [c] * len(xs)    
    cs[0] = 'c'
    print(cs)# each data set has 20 values, starting color is c
    ax.bar(xs, ys, zs=z, zdir ='y', color=cs, alpha=0.8)
    #zdir : direction of plot, alpha : transparency
    
ax.set_xlabel('x')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
# Out:
# ['c', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['c', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g']
# ['c', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b']
# ['c', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y']
